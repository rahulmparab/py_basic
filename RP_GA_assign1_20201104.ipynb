# %%
import pandas as pd

# %%
df=pd.read_excel("DSI_dataset.xlsx",sheet_name = "DSI")

# %%
df.head(5)
# Out:
#    project id                                               name  \
# 0   931747986  CXL - Feature Film - The 24 Hour Kickstarter. ...
# 1  1227406138  Foldable Shoes for Purse- that won't get it di...
# 2      138119                                              STRUM
# 3  1175306310                        Bj���_rk Swan Dress T-Shirt
# 4  1435347461  An Intimate Correspondent at the NCMR 2011 Boston
#
#                                                  url          category  \
# 0  http://www.kickstarter.com/projects/sgillane/c...  Film &amp; Video
# 1  http://www.kickstarter.com/projects/flipslip/f...           Fashion
# 2  http://www.kickstarter.com/projects/185476022/...      Film & Video
# 3  http://www.kickstarter.com/projects/thereport/...               Art
# 4  http://www.kickstarter.com/projects/oagonzalez...        Publishing
#
#       subcategory           location      status     goal  pledged  \
# 0  Narrative Film  San Francisco, CA  successful   5000.0   5018.0
# ...

# %%
df[["project id","status", "funded date"]].head(10)
# Out:
#    project id      status                      funded date
# 0   931747986  successful  Thu, 07 Jul 2011 17:30:17 -0000
# 1  1227406138      failed  Tue, 29 Nov 2011 10:35:18 -0000
# 2      138119        live  Fri, 08 Jun 2012 00:00:31 -0000
# 3  1175306310  successful  Fri, 17 Feb 2012 17:00:00 -0000
# 4  1435347461      failed  Fri, 08 Apr 2011 02:00:00 -0000
# 5  1728704935  successful  Tue, 01 Dec 2009 23:05:00 -0000
# 6   715702673      failed  Wed, 14 Mar 2012 23:14:00 -0000
# 7  1978168386  successful  Fri, 21 Jan 2011 04:10:43 -0000
# 8   657126798  successful  Sat, 24 Apr 2010 02:30:00 -0000
# 9   778178509  successful  Sat, 03 Oct 2009 17:00:00 -0000

# %%
print(type(df['funded date']))
# Out:
# <class 'pandas.core.series.Series'>
